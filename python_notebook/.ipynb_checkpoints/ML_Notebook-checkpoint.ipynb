# %%
import pandas as pd 
import re 
#apps = pd.read_csv('./jobs2.tsv', delimiter='\t',encoding='utf-8')
#apps.head()
#regular=apps[['Title','Description','Requirements', 'City','State']]
#regular.to_csv("job_data.csv", sep='\t', encoding='utf-8')
#cloud_automl=apps[['Title','Description']]


popular_jobs = pd.read_csv('./popular_jobs.csv', delimiter='\t',encoding='utf-8')

popular_jobs.drop(popular_jobs.index[0])

popular_jobs.head();

print(popular_jobs)


pd.DataFrame(popular_jobs[0].values.tolist())


print(popular_jobs[popular_jobs.find(',')+1 :  ])
# Out:
#                                           UserId, JobIds
# 0      767,299322 602736 1077691 625281 898514 103514...
# 1      769,340536 28811 305416 970973 765210 114951 9...
# 2      861,384120 1096879 23663 1003185 787775 47052 ...
# 3      1006,219766 379509 840434 691160 813087 751038...
# 4      1192,208362 919831 508443 630792 1075583 79718...
# 5      2003,627388 31350 752689 579100 263340 615832 ...
# 6      2011,551679 551678 187354 314096 657613 102482...
# 7      2241,360951 224801 360954 373686 3679 60686 62...
# 8      2272,601021 272504 512686 314425 584241 104535...
# 9      2652,617562 862785 229326 567291 17456 1090398...
# 10     2739,7628 789233 151848 489399 1113648 263964 ...
# 11     2750,279887 784895 25483 506959 964509 629039 ...
# 12     2848,802974 98665 10312 246611 187358 741664 1...
# 13     3699,854448 345761 500341 545751 616240 349832...
# 14     3763,39361 496109 817385 614162 1057569 217628...
# ...

# %%
import pandas as pd 
apps = pd.read_csv('./jobs6.tsv', delimiter='\t',encoding='utf-8')
print(apps)

apps.to_csv("jobs.csv", sep='\t')
# Out:
#           JobID  WindowID                                              Title  \
# 0             6         6                           Administrative Assistant
# 1           177         6                                   Maintenance Tech
# 2           179         6                                     Podium Speaker
# 3           181         6                                Sales Professionals
# 4           184         6                           ADMINISTRATIVE ASSISTANT
# 5           188         6             MULTI-PURPOSE MEDICAL OFFICE ASSISTANT
# 6           190         6                                    Admin Assistant
# 7           192         6                                     Office Manager
# 8           195         6                              SENIOR OFFICE MANAGER
# 9           196         6                                       Receptionist
# 10          199         6                                 Quick Service Food
# ...

# %%
import pandas as pd 
apps = pd.read_csv('./apps.tsv', delimiter='\t',encoding='utf-8')
print(apps)

apps.to_csv("apps.csv", sep='\t')
